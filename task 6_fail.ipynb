# %%
class shape:
    width= int()
    heigt=int()
    def __init__(self , width,height):
        self.width=width
        self.height=height
    def area (self):
        return self.width * self.height
a = shape (10 , 5)
print (a.area)
# Out:
# <bound method shape.area of <__main__.shape object at 0x00000169EB4C9940>>

# %%
class person:
    name = "name"
    def __init__(self,name):
        self.name = name
class student (person):
    def __init__(self,name,marks):
        super().__inint__(name)
        self.marks = marks
        if marks > 50:
            print ("pass")
        if marks <= 50:
            print ("fail")
    def prints (self) :
        (self.name  , self.marks) 
sa= student("islam" , 80)
sa.prints()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 15
#      13     def prints (self) :
#      14         (self.name  , self.marks)
# ---> 15 sa= student("islam" , 80)
#      16 sa.prints()
#
# Cell In[30], line 7, in student.__init__(self, name, marks)
#       6 def __init__(self,name,marks):
# ----> 7     super().__inint__(name)
#       8     self.marks = marks
#       9     if marks > 50:
#
# AttributeError: 'super' object has no attribute '__inint__'
